# %% [markdown]
# ## GRU ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout,GRU
from keras import optimizers 
from sqlalchemy import create_engine, text
from scipy.stats import boxcox
import seaborn as sns



seed = 1234
np.random.seed(seed)
plt.style.use('ggplot')

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Import Data

# %%
# Koneksi ke PostgreSQL
# conn = create_engine('postgresql://alvina:alvina@192.168.60.108:5432/harga_komoditas')
conn = create_engine('postgresql://alvina:alvina@127.0.0.1:6543/harga_komoditas')

# Query untuk mengambil data
query = """
SELECT 
    krr.tanggal,  
    krr.harga
FROM "komoditas_rata-rata" as krr
WHERE krr.komoditas_nama = 'Cabe Rawit Merah';
"""

# Mengambil data dari database
with conn.connect() as connection:
    result = connection.execute(text(query))  # Eksekusi query
    data = pd.DataFrame(result.fetchall(), columns=result.keys())

df = data.copy()
# Mengubah kolom tanggal menjadi tipe datetime
df['tanggal'] = pd.to_datetime(df['tanggal'])
df_test = df.tail(90)  # Mengambil 30 data terakhir untuk prediksi
df = df[:-90]  # Menghapus 30 data terakhir dari df untuk training
df.set_index('tanggal', inplace=True)

# %%
# import pandas as pd

# # Baca data dari file CSV
# dataset = pd.read_csv('D:\Teknik Informatika\skripsi\scraping pertanian\data_komoditas_rata-rata.csv')

# # Filter data sesuai kebutuhan
# dataset = dataset[
#     (dataset['komoditas_nama'] == 'Cabe Rawit Merah')
# ].sort_values(by='tanggal').drop(columns=['komoditas_nama', 'id', 'created_at', 'kategori_id', 'satuan'])

# # Copy untuk pemrosesan lebih lanjut
# dataraw = dataset.copy()

# dataraw['tanggal'] = pd.to_datetime(dataraw['tanggal'])
# dataraw = dataset[dataset['tanggal'] <= '2025-04-30']
# dataraw_test = dataset[dataset['tanggal'] > '2025-04-30']


# # Tampilkan dataset hasil filter
# dataraw_test

# %% [markdown]
# ## cek persiapan data

# %% [markdown]
# ### cek outlier

# %%
# boxplot
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(x=df['harga'])
plt.title("Deteksi Outlier dengan Boxplot")
plt.show()

# %%
# z-score statistik
from scipy import stats

z_scores = stats.zscore(df['harga'])  # Hitung Z-score
threshold = 3  # Ambang batas umum untuk outlier
outliers = df[abs(z_scores) > threshold]  # Data yang diidentifikasi sebagai outlier

print("Jumlah outlier ekstrem:", len(outliers))
print(outliers)
# Out:
# Jumlah outlier ekstrem: 7
#              harga
# tanggal
# 2021-03-15  112521
# 2021-03-16  113614
# 2021-03-17  115071
# 2021-03-18  114781
# 2021-03-19  114149
# 2021-03-20  113298
# 2021-03-21  112623

# %% [markdown]
# ### cek distribusi data

# %%
sns.histplot(df['harga'], kde=True)
# Out:
# <Axes: xlabel='harga', ylabel='Count'>

# %% [markdown]
# # Feature Selection

# %%
print(df.head())
print(df.columns)
# Out:
#             harga
# tanggal
# 2021-01-01  52207
# 2021-01-02  58282
# 2021-01-03  60026
# 2021-01-04  69329
# 2021-01-05  72317
# Index(['harga'], dtype='object')

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# ## check missing value

# %%
print(df.isnull().sum())  # Cek jumlah nilai NaN di setiap kolom
# Out:
# harga    0
# dtype: int64

# %% [markdown]
# ## Normalization Min-Max

# %%
df.head()
# Out:
#             harga
# tanggal
# 2021-01-01  52207
# 2021-01-02  58282
# 2021-01-03  60026
# 2021-01-04  69329
# 2021-01-05  72317

# %%
# Normalisasi data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df.values)

# %%
# --- 2. Siapkan Dataset untuk Multistep Forecasting ---
def create_dataset(data, look_back=30, steps_ahead=30):
    X, y = [], []
    for i in range(len(data)-look_back-steps_ahead+1):
        X.append(data[i:(i+look_back), 0])
        y.append(data[(i+look_back):(i+look_back+steps_ahead), 0])
    return np.array(X), np.array(y)

look_back = 90  # Gunakan 30 hari terakhir
steps_ahead = 90  # Prediksi 30 hari ke depan
X, y = create_dataset(scaled_data, look_back, steps_ahead)

# Split data (80% train, 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape untuk GRU: [samples, timesteps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# # Model GRU

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler
from keras import optimizers
import numpy as np
from keras.layers import Bidirectional

# Hyperparameters
learning_rate = 0.0001
batch_size = 256
epochs = 50
steps_ahead = 90  # Pastikan ini sesuai dengan output layer

# --- Arsitektur GRU yang Dioptimasi ---

regressorGRU = Sequential([
    # Layer 1
    GRU(units=256,
        return_sequences=True,
        input_shape=(X_train.shape[1], 1),
        activation='tanh'),
    Dropout(0.3),
    
    # Layer 2 
    GRU(units=128,
        return_sequences=True,
        activation='tanh'),
    Dropout(0.3),
    
    # Layer 3
    GRU(units=64,  # Ditambah dari 32 untuk meningkatkan kapasitas
        return_sequences=False,
        activation='tanh'),
    Dropout(0.2),
    
    # Output layer
    Dense(steps_ahead)
])
# Compile dengan learning rate custom
optimizer = optimizers.Adam(learning_rate=learning_rate)
regressorGRU.compile(optimizer=optimizer, loss='mse')
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# --- Callbacks ---
def lr_scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch != 0:
        return lr * 0.9  # Reduksi learning rate 10% setiap 10 epoch
    return lr

early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
scheduler = LearningRateScheduler(lr_scheduler)
callbacks = [early_stop, scheduler]

# --- Training ---
history = regressorGRU.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=epochs,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 300ms/step - loss: 0.1169 - val_loss: 0.1101 - learning_rate: 1.0000e-04
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 257ms/step - loss: 0.1027 - val_loss: 0.0894 - learning_rate: 1.0000e-04
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - loss: 0.0823 - val_loss: 0.0680 - learning_rate: 1.0000e-04
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 261ms/step - loss: 0.0694 - val_loss: 0.0578 - learning_rate: 1.0000e-04
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - loss: 0.0627 - val_loss: 0.0523 - learning_rate: 1.0000e-04
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - loss: 0.0559 - val_loss: 0.0461 - learning_rate: 1.0000e-04
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - loss: 0.0548 - val_loss: 0.0432 - learning_rate: 1.0000e-04
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - loss: 0.0518 - val_loss: 0.0411 - learning_rate: 1.0000e-04
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - loss: 0.0497 - val_loss: 0.0392 - learning_rate: 1.0000e-04
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - loss: 0.0478 - val_loss: 0.0372 - learning_rate: 1.0000e-04
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 308ms/step - loss: 0.0466 - val_loss: 0.0363 - learning_rate: 9.0000e-05
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - loss: 0.0451 - val_loss: 0.0344 - learning_rate: 9.0000e-05
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 286ms/step - loss: 0.0456 - val_loss: 0.0344 - learning_rate: 9.0000e-05
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - loss: 0.0416 - val_loss: 0.0340 - learning_rate: 9.0000e-05
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 308ms/step - loss: 0.0450 - val_loss: 0.0331 - learning_rate: 9.0000e-05
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - loss: 0.0438 - val_loss: 0.0330 - learning_rate: 9.0000e-05
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 301ms/step - loss: 0.0421 - val_loss: 0.0330 - learning_rate: 9.0000e-05
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - loss: 0.0419 - val_loss: 0.0310 - learning_rate: 9.0000e-05
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - loss: 0.0399 - val_loss: 0.0308 - learning_rate: 9.0000e-05
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - loss: 0.0406 - val_loss: 0.0306 - learning_rate: 9.0000e-05
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - loss: 0.0407 - val_loss: 0.0303 - learning_rate: 8.1000e-05
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - loss: 0.0398 - val_loss: 0.0301 - learning_rate: 8.1000e-05
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - loss: 0.0414 - val_loss: 0.0299 - learning_rate: 8.1000e-05
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - loss: 0.0405 - val_loss: 0.0297 - learning_rate: 8.1000e-05
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - loss: 0.0393 - val_loss: 0.0292 - learning_rate: 8.1000e-05
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - loss: 0.0392 - val_loss: 0.0287 - learning_rate: 8.1000e-05
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 299ms/step - loss: 0.0380 - val_loss: 0.0290 - learning_rate: 8.1000e-05
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 303ms/step - loss: 0.0397 - val_loss: 0.0287 - learning_rate: 8.1000e-05
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - loss: 0.0378 - val_loss: 0.0284 - learning_rate: 8.1000e-05
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - loss: 0.0380 - val_loss: 0.0285 - learning_rate: 8.1000e-05
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - loss: 0.0372 - val_loss: 0.0283 - learning_rate: 7.2900e-05
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - loss: 0.0380 - val_loss: 0.0279 - learning_rate: 7.2900e-05
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 313ms/step - loss: 0.0369 - val_loss: 0.0278 - learning_rate: 7.2900e-05
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - loss: 0.0374 - val_loss: 0.0279 - learning_rate: 7.2900e-05
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - loss: 0.0368 - val_loss: 0.0278 - learning_rate: 7.2900e-05
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - loss: 0.0372 - val_loss: 0.0282 - learning_rate: 7.2900e-05
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 328ms/step - loss: 0.0359 - val_loss: 0.0276 - learning_rate: 7.2900e-05
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 329ms/step - loss: 0.0355 - val_loss: 0.0272 - learning_rate: 7.2900e-05
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - loss: 0.0346 - val_loss: 0.0275 - learning_rate: 7.2900e-05
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 303ms/step - loss: 0.0369 - val_loss: 0.0279 - learning_rate: 7.2900e-05
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - loss: 0.0365 - val_loss: 0.0279 - learning_rate: 6.5610e-05
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - loss: 0.0361 - val_loss: 0.0277 - learning_rate: 6.5610e-05
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 297ms/step - loss: 0.0355 - val_loss: 0.0274 - learning_rate: 6.5610e-05
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 300ms/step - loss: 0.0355 - val_loss: 0.0273 - learning_rate: 6.5610e-05
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 324ms/step - loss: 0.0373 - val_loss: 0.0275 - learning_rate: 6.5610e-05
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - loss: 0.0351 - val_loss: 0.0272 - learning_rate: 6.5610e-05
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 319ms/step - loss: 0.0344 - val_loss: 0.0271 - learning_rate: 6.5610e-05
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 296ms/step - loss: 0.0355 - val_loss: 0.0273 - learning_rate: 6.5610e-05
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 295ms/step - loss: 0.0361 - val_loss: 0.0270 - learning_rate: 6.5610e-05
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - loss: 0.0343 - val_loss: 0.0275 - learning_rate: 6.5610e-05

# %%
# --- Walk-Forward Validation (Implementasi Lengkap) ---
def walk_forward_validation(model, data, look_back, steps_ahead, scaler):
    n = len(data)
    test_size = n - look_back - steps_ahead
    errors = []
    
    for i in range(test_size):
        # Siapkan input (look_back hari) dan target (steps_ahead hari)
        X = data[i:i+look_back]
        y_true = data[i+look_back : i+look_back+steps_ahead]
        
        # Prediksi
        X = np.reshape(X, (1, look_back, 1))
        y_pred = model.predict(X, verbose=0)
        
        # Inverse transform ke skala asli
        y_true = scaler.inverse_transform(y_true.reshape(-1, 1)).flatten()
        y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()
        
        # Hitung MAPE
        mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
        errors.append(mape)
    
    return np.mean(errors)

# %%
# # Hitung MAPE walk-forward
# mape_wf = walk_forward_validation(regressorGRU, scaled_data, look_back=30, steps_ahead=30, scaler=scaler)
# print(f"MAPE Walk-Forward: {mape_wf:.2f}%")

# %%
# df_test.set_index('tanggal', inplace=True)

# %%
# --- Prediksi 30 Hari ke Depan ---
last_sequence = scaled_data[-90:]  # Ambil 30 hari terakhir
last_sequence = np.reshape(last_sequence, (1, 90, 1))
future_predictions = regressorGRU.predict(last_sequence)
future_predictions = scaler.inverse_transform(future_predictions.reshape(-1, 1)).flatten()

df_forecast = pd.DataFrame({
    'tanggal': df_test.index,
    'Actual': df_test['harga'].values,
    'Prediksi_Harga': future_predictions
})
df_forecast.set_index('tanggal', inplace=True)
# Hasil akhir
print("Prediksi 30 Hari ke Depan:")
print(df_forecast)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# Prediksi 30 Hari ke Depan:
#          Actual  Prediksi_Harga
# tanggal
# 1567      67344    66807.187500
# 1568      63953    65374.480469
# 1569      62609    67230.765625
# 1570      61149    63824.105469
# 1571      52856    65418.613281
# ...         ...             ...
# 1652      62132    42593.648438
# 1653      61987    44116.703125
# 1654      61920    40699.281250
# 1655      61330    42272.730469
# 1656      61023    42279.398438
#
# [90 rows x 2 columns]

# %%
# --- 7. Visualisasi Hasil ---
plt.figure(figsize=(10, 6))
# plt.plot(df.index, df['harga'], label='Data Historis', color='blue')
plt.plot(df_forecast['Actual'], label='Aktual', color='blue')
plt.plot(df_forecast['Prediksi_Harga'], label='Prediksi 30 Hari', color='red', linestyle='--')
plt.title(f'Prediksi Harga Cabai rawit Merah 30 Hari ke Depan (GRU Model)')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
# plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
    
    # Hitung RMSE dan MAPE
rmse = np.sqrt(mean_squared_error(df_forecast['Actual'], df_forecast['Prediksi_Harga']))
mape = mean_absolute_percentage_error(df_forecast['Actual'], df_forecast['Prediksi_Harga']) * 100
mae = mean_absolute_error(df_forecast['Actual'], df_forecast['Prediksi_Harga'])
print(f'MAE: {mae:.2f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAPE: {mape:.2f}%')
# Out:
# MAE: 15590.92
# RMSE: 17127.37
# MAPE: 43.99%

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Hitung MAPE
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
# Hitung RMSE dan MAPE
rmse = np.sqrt(mean_squared_error(df_test['harga'], future_predictions))
mape = mean_absolute_percentage_error(df_test['harga'], future_predictions)
print(f'RMSE: {rmse:.2f}')
print(f'MAPE: {mape:.2f}%')
# Out:
# RMSE: 17127.37
# MAPE: 43.99%
