# %% [markdown]
# ## GRU ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout,GRU
from keras import optimizers 
from sqlalchemy import create_engine, text
from scipy.stats import boxcox
from statsmodels.tsa.seasonal import seasonal_decompose

import seaborn as sns



seed = 1234
np.random.seed(seed)
plt.style.use('ggplot')

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Import Data

# %%
# Koneksi ke PostgreSQL
# conn = create_engine('postgresql://alvina:alvina@192.168.60.108:5432/harga_komoditas')
conn = create_engine('postgresql://alvina:alvina@127.0.0.1:6543/harga_komoditas')

# Query untuk mengambil data
query = """
SELECT 
    krr.tanggal,  
    krr.harga
FROM "komoditas_rata-rata" as krr
WHERE krr.komoditas_nama = 'Cabe Rawit Merah';
"""

# Mengambil data dari database
with conn.connect() as connection:
    result = connection.execute(text(query))  # Eksekusi query
    data = pd.DataFrame(result.fetchall(), columns=result.keys())

df = data.copy()

# %%
# Lakukan dekomposisi (asumsi pola musiman mingguan → period=7)
result = seasonal_decompose(data['harga'], model='additive', period=7)

# Plot hasil
plt.figure(figsize=(20, 10))
result.plot()
plt.suptitle("Dekomposisi Waktu: Trend, Seasonal, Residual", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Mengubah kolom tanggal menjadi tipe datetime
df['tanggal'] = pd.to_datetime(df['tanggal'])
df_test = df.tail(90)  # Mengambil 30 data terakhir untuk prediksi
df_train = df[:-90]  # Menghapus 30 data terakhir dari df untuk training
df_train.set_index('tanggal', inplace=True)
df, lambda_ = boxcox(df_train['harga'])  # Transformasi Box-Cox
df = pd.DataFrame(df, columns=['harga'])
df = df.set_index(df_train.index)  # Set index tanggal untuk df
df_test.set_index('tanggal', inplace=True)

# %%
# import pandas as pd

# # Baca data dari file CSV
# dataset = pd.read_csv('D:\Teknik Informatika\skripsi\scraping pertanian\data_komoditas_rata-rata.csv')

# # Filter data sesuai kebutuhan
# dataset = dataset[
#     (dataset['komoditas_nama'] == 'Cabe Rawit Merah')
# ].sort_values(by='tanggal').drop(columns=['komoditas_nama', 'id', 'created_at', 'kategori_id', 'satuan'])

# # Copy untuk pemrosesan lebih lanjut
# dataraw = dataset.copy()

# dataraw['tanggal'] = pd.to_datetime(dataraw['tanggal'])
# dataraw = dataset[dataset['tanggal'] <= '2025-04-30']
# dataraw_test = dataset[dataset['tanggal'] > '2025-04-30']


# # Tampilkan dataset hasil filter
# dataraw_test

# %% [markdown]
# ## cek persiapan data

# %% [markdown]
# ### cek outlier

# %%
# boxplot
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(x=df['harga'])
plt.title("Deteksi Outlier dengan Boxplot")
plt.show()

# %%
# z-score statistik
from scipy import stats

z_scores = stats.zscore(df['harga'])  # Hitung Z-score
threshold = 3  # Ambang batas umum untuk outlier
outliers = df[abs(z_scores) > threshold]  # Data yang diidentifikasi sebagai outlier

print("Jumlah outlier ekstrem:", len(outliers))
print(outliers)
# Out:
# Jumlah outlier ekstrem: 0
# Empty DataFrame
# Columns: [harga]
# Index: []

# %% [markdown]
# ### cek distribusi data

# %%
sns.histplot(df['harga'], kde=True)
# Out:
# <Axes: xlabel='harga', ylabel='Count'>

# %% [markdown]
# # Feature Selection

# %%
print(df.head())
print(df.columns)
# Out:
#                 harga
# tanggal
# 2021-01-01  12.714106
# 2021-01-02  12.863950
# 2021-01-03  12.904165
# 2021-01-04  13.101174
# 2021-01-05  13.159021
# Index(['harga'], dtype='object')

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# ## check missing value

# %%
print(df.isnull().sum())  # Cek jumlah nilai NaN di setiap kolom
# Out:
# harga    0
# dtype: int64

# %% [markdown]
# ## Normalization Min-Max

# %%
df.head()
# Out:
#                 harga
# tanggal
# 2021-01-01  12.714106
# 2021-01-02  12.863950
# 2021-01-03  12.904165
# 2021-01-04  13.101174
# 2021-01-05  13.159021

# %%
# Normalisasi data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df.values)

# %%
# --- 2. Siapkan Dataset untuk Multistep Forecasting ---
def create_dataset(data, look_back=30, steps_ahead=30):
    X, y = [], []
    for i in range(len(data)-look_back-steps_ahead+1):
        X.append(data[i:(i+look_back), 0])
        y.append(data[(i+look_back):(i+look_back+steps_ahead), 0])
    return np.array(X), np.array(y)

look_back = 90  # Gunakan 30 hari terakhir
steps_ahead = 90  # Prediksi 30 hari ke depan
X, y = create_dataset(scaled_data, look_back, steps_ahead)

# Split data (80% train, 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape untuk GRU: [samples, timesteps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# # Model GRU

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler
from keras import optimizers
import numpy as np
from keras.layers import Bidirectional

# Hyperparameters
learning_rate = 0.0001
batch_size = 256
epochs = 100
steps_ahead = 90  # Pastikan ini sesuai dengan output layer

# --- Arsitektur GRU yang Dioptimasi ---

regressorGRU = Sequential([
    # Layer 1
    GRU(units=60,
        return_sequences=True,
        input_shape=(X_train.shape[1], 1),
        activation='tanh'),
    Dropout(0.3),
    
    # Layer 2 
    GRU(units=80,
        return_sequences=True,
        activation='tanh'),
    Dropout(0.3),
    
    # Layer 3
    GRU(units=120,  # Ditambah dari 32 untuk meningkatkan kapasitas
        return_sequences=False,
        activation='tanh'),
    Dropout(0.2),
    
    # Output layer
    Dense(steps_ahead)
])
# Compile dengan learning rate custom
optimizer = optimizers.Adam(learning_rate=learning_rate)
regressorGRU.compile(optimizer=optimizer, loss='mse')
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# --- Callbacks ---
def lr_scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch != 0:
        return lr * 0.9  # Reduksi learning rate 10% setiap 10 epoch
    return lr

early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
scheduler = LearningRateScheduler(lr_scheduler)
callbacks = [early_stop, scheduler]

# --- Training ---
history = regressorGRU.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 645ms/step - loss: 0.2734 - val_loss: 0.2818 - learning_rate: 1.0000e-04
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - loss: 0.2687 - val_loss: 0.2765 - learning_rate: 1.0000e-04
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - loss: 0.2577 - val_loss: 0.2712 - learning_rate: 1.0000e-04
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 359ms/step - loss: 0.2633 - val_loss: 0.2654 - learning_rate: 1.0000e-04
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 386ms/step - loss: 0.2511 - val_loss: 0.2588 - learning_rate: 1.0000e-04
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - loss: 0.2421 - val_loss: 0.2510 - learning_rate: 1.0000e-04
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 351ms/step - loss: 0.2370 - val_loss: 0.2415 - learning_rate: 1.0000e-04
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 338ms/step - loss: 0.2247 - val_loss: 0.2298 - learning_rate: 1.0000e-04
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 338ms/step - loss: 0.2116 - val_loss: 0.2151 - learning_rate: 1.0000e-04
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 356ms/step - loss: 0.1978 - val_loss: 0.1970 - learning_rate: 1.0000e-04
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 350ms/step - loss: 0.1812 - val_loss: 0.1773 - learning_rate: 9.0000e-05
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - loss: 0.1632 - val_loss: 0.1550 - learning_rate: 9.0000e-05
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 620ms/step - loss: 0.1435 - val_loss: 0.1319 - learning_rate: 9.0000e-05
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 542ms/step - loss: 0.1262 - val_loss: 0.1115 - learning_rate: 9.0000e-05
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 542ms/step - loss: 0.1124 - val_loss: 0.0961 - learning_rate: 9.0000e-05
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 559ms/step - loss: 0.1041 - val_loss: 0.0853 - learning_rate: 9.0000e-05
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 508ms/step - loss: 0.0954 - val_loss: 0.0786 - learning_rate: 9.0000e-05
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 535ms/step - loss: 0.0886 - val_loss: 0.0738 - learning_rate: 9.0000e-05
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 511ms/step - loss: 0.0856 - val_loss: 0.0694 - learning_rate: 9.0000e-05
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 504ms/step - loss: 0.0803 - val_loss: 0.0655 - learning_rate: 9.0000e-05
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 500ms/step - loss: 0.0791 - val_loss: 0.0614 - learning_rate: 8.1000e-05
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 497ms/step - loss: 0.0743 - val_loss: 0.0588 - learning_rate: 8.1000e-05
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - loss: 0.0736 - val_loss: 0.0567 - learning_rate: 8.1000e-05
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 507ms/step - loss: 0.0741 - val_loss: 0.0553 - learning_rate: 8.1000e-05
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 494ms/step - loss: 0.0703 - val_loss: 0.0545 - learning_rate: 8.1000e-05
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 524ms/step - loss: 0.0706 - val_loss: 0.0535 - learning_rate: 8.1000e-05
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 484ms/step - loss: 0.0687 - val_loss: 0.0526 - learning_rate: 8.1000e-05
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 514ms/step - loss: 0.0676 - val_loss: 0.0518 - learning_rate: 8.1000e-05
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 490ms/step - loss: 0.0669 - val_loss: 0.0513 - learning_rate: 8.1000e-05
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 524ms/step - loss: 0.0663 - val_loss: 0.0507 - learning_rate: 8.1000e-05
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 542ms/step - loss: 0.0650 - val_loss: 0.0501 - learning_rate: 7.2900e-05
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 525ms/step - loss: 0.0655 - val_loss: 0.0499 - learning_rate: 7.2900e-05
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 531ms/step - loss: 0.0642 - val_loss: 0.0491 - learning_rate: 7.2900e-05
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 507ms/step - loss: 0.0640 - val_loss: 0.0482 - learning_rate: 7.2900e-05
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 509ms/step - loss: 0.0657 - val_loss: 0.0480 - learning_rate: 7.2900e-05
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 511ms/step - loss: 0.0624 - val_loss: 0.0481 - learning_rate: 7.2900e-05
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 511ms/step - loss: 0.0642 - val_loss: 0.0482 - learning_rate: 7.2900e-05
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 514ms/step - loss: 0.0615 - val_loss: 0.0478 - learning_rate: 7.2900e-05
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 509ms/step - loss: 0.0621 - val_loss: 0.0471 - learning_rate: 7.2900e-05
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 545ms/step - loss: 0.0620 - val_loss: 0.0467 - learning_rate: 7.2900e-05
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - loss: 0.0633 - val_loss: 0.0466 - learning_rate: 6.5610e-05
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 487ms/step - loss: 0.0615 - val_loss: 0.0467 - learning_rate: 6.5610e-05
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 480ms/step - loss: 0.0609 - val_loss: 0.0464 - learning_rate: 6.5610e-05
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 488ms/step - loss: 0.0596 - val_loss: 0.0461 - learning_rate: 6.5610e-05
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 481ms/step - loss: 0.0610 - val_loss: 0.0455 - learning_rate: 6.5610e-05
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 494ms/step - loss: 0.0603 - val_loss: 0.0450 - learning_rate: 6.5610e-05
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 498ms/step - loss: 0.0595 - val_loss: 0.0449 - learning_rate: 6.5610e-05
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 519ms/step - loss: 0.0603 - val_loss: 0.0449 - learning_rate: 6.5610e-05
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 508ms/step - loss: 0.0592 - val_loss: 0.0454 - learning_rate: 6.5610e-05
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 511ms/step - loss: 0.0589 - val_loss: 0.0453 - learning_rate: 6.5610e-05
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 475ms/step - loss: 0.0595 - val_loss: 0.0449 - learning_rate: 5.9049e-05
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 493ms/step - loss: 0.0596 - val_loss: 0.0445 - learning_rate: 5.9049e-05
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 495ms/step - loss: 0.0589 - val_loss: 0.0440 - learning_rate: 5.9049e-05
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 521ms/step - loss: 0.0591 - val_loss: 0.0439 - learning_rate: 5.9049e-05
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 518ms/step - loss: 0.0588 - val_loss: 0.0438 - learning_rate: 5.9049e-05
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 504ms/step - loss: 0.0588 - val_loss: 0.0437 - learning_rate: 5.9049e-05
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 486ms/step - loss: 0.0594 - val_loss: 0.0439 - learning_rate: 5.9049e-05
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 510ms/step - loss: 0.0575 - val_loss: 0.0438 - learning_rate: 5.9049e-05
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 512ms/step - loss: 0.0586 - val_loss: 0.0434 - learning_rate: 5.9049e-05
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 507ms/step - loss: 0.0593 - val_loss: 0.0434 - learning_rate: 5.9049e-05
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 480ms/step - loss: 0.0581 - val_loss: 0.0432 - learning_rate: 5.3144e-05
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 548ms/step - loss: 0.0579 - val_loss: 0.0431 - learning_rate: 5.3144e-05
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 497ms/step - loss: 0.0573 - val_loss: 0.0430 - learning_rate: 5.3144e-05
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 529ms/step - loss: 0.0582 - val_loss: 0.0429 - learning_rate: 5.3144e-05
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 516ms/step - loss: 0.0572 - val_loss: 0.0429 - learning_rate: 5.3144e-05
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 535ms/step - loss: 0.0579 - val_loss: 0.0427 - learning_rate: 5.3144e-05
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 521ms/step - loss: 0.0558 - val_loss: 0.0424 - learning_rate: 5.3144e-05
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 555ms/step - loss: 0.0564 - val_loss: 0.0423 - learning_rate: 5.3144e-05
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 479ms/step - loss: 0.0568 - val_loss: 0.0421 - learning_rate: 5.3144e-05
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 559ms/step - loss: 0.0560 - val_loss: 0.0420 - learning_rate: 5.3144e-05
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 523ms/step - loss: 0.0565 - val_loss: 0.0420 - learning_rate: 4.7830e-05
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 505ms/step - loss: 0.0567 - val_loss: 0.0421 - learning_rate: 4.7830e-05
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 505ms/step - loss: 0.0561 - val_loss: 0.0419 - learning_rate: 4.7830e-05
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 525ms/step - loss: 0.0569 - val_loss: 0.0416 - learning_rate: 4.7830e-05
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 500ms/step - loss: 0.0564 - val_loss: 0.0416 - learning_rate: 4.7830e-05
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 503ms/step - loss: 0.0557 - val_loss: 0.0414 - learning_rate: 4.7830e-05
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 504ms/step - loss: 0.0559 - val_loss: 0.0415 - learning_rate: 4.7830e-05
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 532ms/step - loss: 0.0562 - val_loss: 0.0417 - learning_rate: 4.7830e-05
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 569ms/step - loss: 0.0557 - val_loss: 0.0416 - learning_rate: 4.7830e-05
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 537ms/step - loss: 0.0541 - val_loss: 0.0412 - learning_rate: 4.7830e-05
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 509ms/step - loss: 0.0552 - val_loss: 0.0409 - learning_rate: 4.3047e-05
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - loss: 0.0559 - val_loss: 0.0409 - learning_rate: 4.3047e-05
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - loss: 0.0559 - val_loss: 0.0410 - learning_rate: 4.3047e-05
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 505ms/step - loss: 0.0551 - val_loss: 0.0409 - learning_rate: 4.3047e-05
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 511ms/step - loss: 0.0543 - val_loss: 0.0404 - learning_rate: 4.3047e-05
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 533ms/step - loss: 0.0549 - val_loss: 0.0400 - learning_rate: 4.3047e-05
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 541ms/step - loss: 0.0546 - val_loss: 0.0401 - learning_rate: 4.3047e-05
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 547ms/step - loss: 0.0550 - val_loss: 0.0406 - learning_rate: 4.3047e-05
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 535ms/step - loss: 0.0549 - val_loss: 0.0407 - learning_rate: 4.3047e-05
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 555ms/step - loss: 0.0539 - val_loss: 0.0404 - learning_rate: 4.3047e-05
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 545ms/step - loss: 0.0531 - val_loss: 0.0399 - learning_rate: 3.8742e-05
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 540ms/step - loss: 0.0547 - val_loss: 0.0398 - learning_rate: 3.8742e-05
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 532ms/step - loss: 0.0546 - val_loss: 0.0396 - learning_rate: 3.8742e-05
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 539ms/step - loss: 0.0542 - val_loss: 0.0397 - learning_rate: 3.8742e-05
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - loss: 0.0539 - val_loss: 0.0399 - learning_rate: 3.8742e-05
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 471ms/step - loss: 0.0534 - val_loss: 0.0396 - learning_rate: 3.8742e-05
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 482ms/step - loss: 0.0539 - val_loss: 0.0397 - learning_rate: 3.8742e-05
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 457ms/step - loss: 0.0543 - val_loss: 0.0396 - learning_rate: 3.8742e-05
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 523ms/step - loss: 0.0543 - val_loss: 0.0396 - learning_rate: 3.8742e-05
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 555ms/step - loss: 0.0551 - val_loss: 0.0394 - learning_rate: 3.8742e-05

# %%
y_pred = regressorGRU.predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step

# %%
from scipy.special import inv_boxcox
# Inverse transform untuk mendapatkan harga asli
y_pred_inverse = scaler.inverse_transform(y_pred)
y_pred_inverse = inv_boxcox(y_pred_inverse, lambda_)

y_test_inverse = scaler.inverse_transform(y_test)
y_test_inverse = inv_boxcox(y_test_inverse, lambda_)
# mae = mean_absolute_error(y_test_inverse, y_pred_inverse)
# print(f"MAE: {mae:.2f}")
# print(f"RMSE: {np.sqrt(mean_squared_error(y_test_inverse, y_pred_inverse)):.2f}")
# Plot hasil prediksi
plt.plot(df_test.index, y_test_inverse[0], label='Data Asli', color='blue')
plt.plot(df_test.index, y_pred_inverse[0], label='Prediksi', color='red')
plt.title('Perbandingan 1 Sampel Prediksi vs Aktual (90 Hari)')
plt.legend()
plt.show()

# %%
# --- Walk-Forward Validation (Implementasi Lengkap) ---
def walk_forward_validation(model, data, look_back, steps_ahead, scaler):
    n = len(data)
    test_size = n - look_back - steps_ahead
    errors = []
    
    for i in range(test_size):
        # Siapkan input (look_back hari) dan target (steps_ahead hari)
        X = data[i:i+look_back]
        y_true = data[i+look_back : i+look_back+steps_ahead]
        
        # Prediksi
        X = np.reshape(X, (1, look_back, 1))
        y_pred = model.predict(X, verbose=0)
        
        # Inverse transform ke skala asli
        y_true = scaler.inverse_transform(y_true.reshape(-1, 1)).flatten()
        y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()
        
        # Hitung MAPE
        mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
        errors.append(mape)
    
    return np.mean(errors)

# %%
# df_test.set_index('tanggal', inplace=True)

# %%
from scipy.special import inv_boxcox
# --- Prediksi 30 Hari ke Depan ---
last_sequence = scaled_data[-90:]  # Ambil 30 hari terakhir
last_sequence = np.reshape(last_sequence, (1, 90, 1))
future_predictions = regressorGRU.predict(last_sequence)
future_predictions = scaler.inverse_transform(future_predictions.reshape(-1, 1)).flatten()
future_predictions = inv_boxcox(future_predictions, lambda_)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step

# %%
print(len(future_predictions))
print(len(df_test))
# Out:
# 90
# 90

# %%
# Hasil akhir
print("Prediksi 30 Hari ke Depan:")
print(pd.DataFrame({
    'tanggal': df_test.index,
    'Actual': df_test['harga'].values,
    'Prediksi_Harga': future_predictions
}))
# Out:
# Prediksi 30 Hari ke Depan:
#       tanggal  Actual  Prediksi_Harga
# 0  2025-04-17   67344    50261.511709
# 1  2025-04-18   63953    48983.511137
# 2  2025-04-19   62609    48906.236051
# 3  2025-04-20   61149    49697.964200
# 4  2025-04-21   52856    46435.532313
# ..        ...     ...             ...
# 85 2025-07-11   62132    42213.019238
# 86 2025-07-12   61987    40623.766774
# 87 2025-07-13   61920    42629.249625
# 88 2025-07-14   61330    42806.949495
# 89 2025-07-15   61023    42184.780100
#
# [90 rows x 3 columns]

# %%
# --- 7. Visualisasi Hasil ---
plt.figure(figsize=(10, 6))
# plt.plot(df.index, df['harga'], label='Data Historis', color='blue')
plt.plot(df_test, label='Aktual', color='blue')
plt.plot(df_test.index,future_predictions, label='Prediksi 30 Hari', color='red', linestyle='--')
plt.title(f'Prediksi Harga Cabai rawit Merah 30 Hari ke Depan (GRU Model)')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
# Hitung MAPE
    
# Hitung RMSE dan MAPE
rmse = np.sqrt(mean_squared_error(df_test['harga'], future_predictions))
mape = mean_absolute_percentage_error(df_test['harga'], future_predictions) * 100
mae = mean_absolute_error(df_test['harga'], future_predictions)
print(f'MAE: {mae:.2f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAPE: {mape:.2f}%')
# Out:
# MAE: 13136.68
# RMSE: 14316.90
# MAPE: 36.23%
