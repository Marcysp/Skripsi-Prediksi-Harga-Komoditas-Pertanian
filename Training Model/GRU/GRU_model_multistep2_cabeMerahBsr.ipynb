# %% [markdown]
# ## GRU ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout,GRU
from keras import optimizers 
from sqlalchemy import create_engine, text
from scipy.stats import boxcox
import seaborn as sns



seed = 1234
np.random.seed(seed)
plt.style.use('ggplot')

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Import Data

# %%
# Koneksi ke PostgreSQL
conn = create_engine('postgresql://alvina:alvina@192.168.60.108:5432/harga_komoditas')

# Query untuk mengambil data
query = """
SELECT 
    krr.tanggal,  
    krr.harga
FROM "komoditas_rata-rata" as krr
WHERE krr.komoditas_nama = 'Cabe Merah Besar';
"""

# Mengambil data dari database
with conn.connect() as connection:
    result = connection.execute(text(query))  # Eksekusi query
    data = pd.DataFrame(result.fetchall(), columns=result.keys())

df = data.copy()
# Mengubah kolom tanggal menjadi tipe datetime
df['tanggal'] = pd.to_datetime(df['tanggal'])
df_test = df.tail(90)  # Mengambil 30 data terakhir untuk prediksi
df_train = df[:-90]  # Menghapus 30 data terakhir dari df untuk training
df_train.set_index('tanggal', inplace=True)
df, lambda_ = boxcox(df_train['harga'])  # Transformasi Box-Cox
df = pd.DataFrame(df, columns=['harga'])
df = df.set_index(df_train.index)  # Set index tanggal untuk df
df_test.set_index('tanggal', inplace=True)

# %%
# import pandas as pd

# # Baca data dari file CSV
# dataset = pd.read_csv('D:\Teknik Informatika\skripsi\scraping pertanian\data_komoditas_rata-rata.csv')

# # Filter data sesuai kebutuhan
# dataset = dataset[
#     (dataset['komoditas_nama'] == 'Cabe Rawit Merah')
# ].sort_values(by='tanggal').drop(columns=['komoditas_nama', 'id', 'created_at', 'kategori_id', 'satuan'])

# # Copy untuk pemrosesan lebih lanjut
# dataraw = dataset.copy()

# dataraw['tanggal'] = pd.to_datetime(dataraw['tanggal'])
# dataraw = dataset[dataset['tanggal'] <= '2025-04-30']
# dataraw_test = dataset[dataset['tanggal'] > '2025-04-30']


# # Tampilkan dataset hasil filter
# dataraw_test

# %% [markdown]
# ## cek persiapan data

# %% [markdown]
# ### cek outlier

# %%
# boxplot
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(x=df['harga'])
plt.title("Deteksi Outlier dengan Boxplot")
plt.show()

# %%
# z-score statistik
from scipy import stats

z_scores = stats.zscore(df['harga'])  # Hitung Z-score
threshold = 3  # Ambang batas umum untuk outlier
outliers = df[abs(z_scores) > threshold]  # Data yang diidentifikasi sebagai outlier

print("Jumlah outlier ekstrem:", len(outliers))
print(outliers)
# Out:
# Jumlah outlier ekstrem: 0
# Empty DataFrame
# Columns: [harga]
# Index: []

# %% [markdown]
# ### cek distribusi data

# %%
sns.histplot(df['harga'], kde=True)
# Out:
# <Axes: xlabel='harga', ylabel='Count'>

# %% [markdown]
# # Feature Selection

# %%
print(df.head())
print(df.columns)
# Out:
#                harga
# tanggal
# 2021-01-01  8.825043
# 2021-01-02  8.855620
# 2021-01-03  8.852313
# 2021-01-04  8.813436
# 2021-01-05  8.787706
# Index(['harga'], dtype='object')

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# ## check missing value

# %%
print(df.isnull().sum())  # Cek jumlah nilai NaN di setiap kolom
# Out:
# harga    0
# dtype: int64

# %% [markdown]
# ## Normalization Min-Max

# %%
df.head()
# Out:
#                harga
# tanggal
# 2021-01-01  8.825043
# 2021-01-02  8.855620
# 2021-01-03  8.852313
# 2021-01-04  8.813436
# 2021-01-05  8.787706

# %%
# Normalisasi data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df.values)

# %%
# --- 2. Siapkan Dataset untuk Multistep Forecasting ---
def create_dataset(data, look_back=30, steps_ahead=30):
    X, y = [], []
    for i in range(len(data)-look_back-steps_ahead+1):
        X.append(data[i:(i+look_back), 0])
        y.append(data[(i+look_back):(i+look_back+steps_ahead), 0])
    return np.array(X), np.array(y)

look_back = 90  # Gunakan 30 hari terakhir
steps_ahead = 90  # Prediksi 30 hari ke depan
X, y = create_dataset(scaled_data, look_back, steps_ahead)

# Split data (80% train, 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape untuk GRU: [samples, timesteps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# # Model GRU

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler
from keras import optimizers
import numpy as np
from keras.layers import Bidirectional

# Hyperparameters
learning_rate = 0.0001
batch_size = 256
epochs = 50
steps_ahead = 90  # Pastikan ini sesuai dengan output layer

# --- Arsitektur GRU yang Dioptimasi ---

regressorGRU = Sequential([
    # Layer 1
    GRU(units=256,
        return_sequences=True,
        input_shape=(X_train.shape[1], 1),
        activation='tanh'),
    Dropout(0.3),
    
    # Layer 2 
    GRU(units=128,
        return_sequences=True,
        activation='tanh'),
    Dropout(0.3),
    
    # Layer 3
    GRU(units=64,  # Ditambah dari 32 untuk meningkatkan kapasitas
        return_sequences=False,
        activation='tanh'),
    Dropout(0.2),
    
    # Output layer
    Dense(steps_ahead)
])
# Compile dengan learning rate custom
optimizer = optimizers.Adam(learning_rate=learning_rate)
regressorGRU.compile(optimizer=optimizer, loss='mse')
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# --- Callbacks ---
def lr_scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch != 0:
        return lr * 0.9  # Reduksi learning rate 10% setiap 10 epoch
    return lr

early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
scheduler = LearningRateScheduler(lr_scheduler)
callbacks = [early_stop, scheduler]

# --- Training ---
history = regressorGRU.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 13s 759ms/step - loss: 0.3087 - val_loss: 0.2245 - learning_rate: 1.0000e-04
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 497ms/step - loss: 0.2971 - val_loss: 0.2171 - learning_rate: 1.0000e-04
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 501ms/step - loss: 0.2912 - val_loss: 0.2091 - learning_rate: 1.0000e-04
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 502ms/step - loss: 0.2726 - val_loss: 0.1999 - learning_rate: 1.0000e-04
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 495ms/step - loss: 0.2680 - val_loss: 0.1888 - learning_rate: 1.0000e-04
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 493ms/step - loss: 0.2500 - val_loss: 0.1753 - learning_rate: 1.0000e-04
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 496ms/step - loss: 0.2292 - val_loss: 0.1592 - learning_rate: 1.0000e-04
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 494ms/step - loss: 0.2097 - val_loss: 0.1415 - learning_rate: 1.0000e-04
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 498ms/step - loss: 0.1852 - val_loss: 0.1251 - learning_rate: 1.0000e-04
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 491ms/step - loss: 0.1674 - val_loss: 0.1123 - learning_rate: 1.0000e-04
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 499ms/step - loss: 0.1537 - val_loss: 0.1023 - learning_rate: 9.0000e-05
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 552ms/step - loss: 0.1408 - val_loss: 0.0936 - learning_rate: 9.0000e-05
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 545ms/step - loss: 0.1300 - val_loss: 0.0869 - learning_rate: 9.0000e-05
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 680ms/step - loss: 0.1246 - val_loss: 0.0813 - learning_rate: 9.0000e-05
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 780ms/step - loss: 0.1175 - val_loss: 0.0765 - learning_rate: 9.0000e-05
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 691ms/step - loss: 0.1112 - val_loss: 0.0728 - learning_rate: 9.0000e-05
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 667ms/step - loss: 0.1083 - val_loss: 0.0699 - learning_rate: 9.0000e-05
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 671ms/step - loss: 0.1046 - val_loss: 0.0675 - learning_rate: 9.0000e-05
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 668ms/step - loss: 0.1019 - val_loss: 0.0655 - learning_rate: 9.0000e-05
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 672ms/step - loss: 0.0974 - val_loss: 0.0636 - learning_rate: 9.0000e-05
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 664ms/step - loss: 0.0963 - val_loss: 0.0620 - learning_rate: 8.1000e-05
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 666ms/step - loss: 0.0918 - val_loss: 0.0606 - learning_rate: 8.1000e-05
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 664ms/step - loss: 0.0892 - val_loss: 0.0594 - learning_rate: 8.1000e-05
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 655ms/step - loss: 0.0879 - val_loss: 0.0582 - learning_rate: 8.1000e-05
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 659ms/step - loss: 0.0860 - val_loss: 0.0572 - learning_rate: 8.1000e-05
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 692ms/step - loss: 0.0839 - val_loss: 0.0562 - learning_rate: 8.1000e-05
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 778ms/step - loss: 0.0831 - val_loss: 0.0553 - learning_rate: 8.1000e-05
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 706ms/step - loss: 0.0804 - val_loss: 0.0546 - learning_rate: 8.1000e-05
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 674ms/step - loss: 0.0807 - val_loss: 0.0539 - learning_rate: 8.1000e-05
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 750ms/step - loss: 0.0793 - val_loss: 0.0533 - learning_rate: 8.1000e-05
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 667ms/step - loss: 0.0760 - val_loss: 0.0528 - learning_rate: 7.2900e-05
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 678ms/step - loss: 0.0759 - val_loss: 0.0524 - learning_rate: 7.2900e-05
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 726ms/step - loss: 0.0735 - val_loss: 0.0520 - learning_rate: 7.2900e-05
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 763ms/step - loss: 0.0743 - val_loss: 0.0515 - learning_rate: 7.2900e-05
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 676ms/step - loss: 0.0714 - val_loss: 0.0512 - learning_rate: 7.2900e-05
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 661ms/step - loss: 0.0705 - val_loss: 0.0509 - learning_rate: 7.2900e-05
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 675ms/step - loss: 0.0708 - val_loss: 0.0504 - learning_rate: 7.2900e-05
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 662ms/step - loss: 0.0693 - val_loss: 0.0501 - learning_rate: 7.2900e-05
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 652ms/step - loss: 0.0692 - val_loss: 0.0498 - learning_rate: 7.2900e-05
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 649ms/step - loss: 0.0682 - val_loss: 0.0496 - learning_rate: 7.2900e-05
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 646ms/step - loss: 0.0666 - val_loss: 0.0494 - learning_rate: 6.5610e-05
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 657ms/step - loss: 0.0686 - val_loss: 0.0493 - learning_rate: 6.5610e-05
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 673ms/step - loss: 0.0682 - val_loss: 0.0490 - learning_rate: 6.5610e-05
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 669ms/step - loss: 0.0681 - val_loss: 0.0488 - learning_rate: 6.5610e-05
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 655ms/step - loss: 0.0653 - val_loss: 0.0487 - learning_rate: 6.5610e-05
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 684ms/step - loss: 0.0645 - val_loss: 0.0486 - learning_rate: 6.5610e-05
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 646ms/step - loss: 0.0634 - val_loss: 0.0485 - learning_rate: 6.5610e-05
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 665ms/step - loss: 0.0638 - val_loss: 0.0484 - learning_rate: 6.5610e-05
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 818ms/step - loss: 0.0635 - val_loss: 0.0481 - learning_rate: 6.5610e-05
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 782ms/step - loss: 0.0632 - val_loss: 0.0479 - learning_rate: 6.5610e-05

# %%
# --- Walk-Forward Validation (Implementasi Lengkap) ---
def walk_forward_validation(model, data, look_back, steps_ahead, scaler):
    n = len(data)
    test_size = n - look_back - steps_ahead
    errors = []
    
    for i in range(test_size):
        # Siapkan input (look_back hari) dan target (steps_ahead hari)
        X = data[i:i+look_back]
        y_true = data[i+look_back : i+look_back+steps_ahead]
        
        # Prediksi
        X = np.reshape(X, (1, look_back, 1))
        y_pred = model.predict(X, verbose=0)
        
        # Inverse transform ke skala asli
        y_true = scaler.inverse_transform(y_true.reshape(-1, 1)).flatten()
        y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()
        
        # Hitung MAPE
        mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
        errors.append(mape)
    
    return np.mean(errors)

# %%
# df_test.set_index('tanggal', inplace=True)

# %%
from scipy.special import inv_boxcox
# --- Prediksi 30 Hari ke Depan ---
last_sequence = scaled_data[-90:]  # Ambil 30 hari terakhir
last_sequence = np.reshape(last_sequence, (1, 90, 1))
future_predictions = regressorGRU.predict(last_sequence)
future_predictions = scaler.inverse_transform(future_predictions.reshape(-1, 1)).flatten()
future_predictions = inv_boxcox(future_predictions, lambda_)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 854ms/step

# %%
print(len(future_predictions))
print(len(df_test))
# Out:
# 90
# 90

# %%
# Hasil akhir
print("Prediksi 30 Hari ke Depan:")
print(pd.DataFrame({
    'tanggal': df_test.index,
    'Actual': df_test['harga'].values,
    'Prediksi_Harga': future_predictions
}))
# Out:
# Prediksi 30 Hari ke Depan:
#       tanggal  Actual  Prediksi_Harga
# 0  2025-04-02   49700    40979.314256
# 1  2025-04-03   47621    41201.751626
# 2  2025-04-04   45688    35406.226806
# 3  2025-04-05   43862    31676.723478
# 4  2025-04-06   42862    36864.767340
# ..        ...     ...             ...
# 85 2025-06-26   28782    36490.484273
# 86 2025-06-27   28678    39047.639311
# 87 2025-06-28   28812    38712.042707
# 88 2025-06-29   29004    39530.293145
# 89 2025-06-30   29669    39362.594829
#
# [90 rows x 3 columns]

# %%
# --- 7. Visualisasi Hasil ---
plt.figure(figsize=(10, 6))
# plt.plot(df.index, df['harga'], label='Data Historis', color='blue')
plt.plot(df_test, label='Aktual', color='blue')
plt.plot(df_test.index,future_predictions, label='Prediksi 30 Hari', color='red', linestyle='--')
plt.title(f'Prediksi Harga Cabai rawit Merah 30 Hari ke Depan (GRU Model)')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
# Hitung RMSE dan MAPE
rmse = np.sqrt(mean_squared_error(df_test['harga'], future_predictions))
mape = mean_absolute_percentage_error(df_test['harga'], future_predictions) * 100
mae = mean_absolute_error(df_test['harga'], future_predictions)
print(f'MAE: {mae:.2f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAPE: {mape:.2f}%')
# Out:
# MAE: 6517.44
# RMSE: 7281.78
# MAPE: 20.83%
