# %% [markdown]
# ## GRU ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout,GRU
from keras import optimizers 
from sqlalchemy import create_engine, text
from scipy.stats import boxcox
import seaborn as sns



seed = 1234
np.random.seed(seed)
plt.style.use('ggplot')

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Import Data

# %%
# Koneksi ke PostgreSQL
conn = create_engine('postgresql://alvina:alvina@192.168.60.108:5432/harga_komoditas')

# Query untuk mengambil data
query = """
SELECT 
    krr.tanggal,  
    krr.harga
FROM "komoditas_rata-rata" as krr
WHERE krr.komoditas_nama = 'Tomat Merah';
"""

# Mengambil data dari database
with conn.connect() as connection:
    result = connection.execute(text(query))  # Eksekusi query
    data = pd.DataFrame(result.fetchall(), columns=result.keys())

df = data.copy()
# Mengubah kolom tanggal menjadi tipe datetime
df['tanggal'] = pd.to_datetime(df['tanggal'])
df_test = df.tail(90)  # Mengambil 30 data terakhir untuk prediksi
df_train = df[:-90]  # Menghapus 30 data terakhir dari df untuk training
df_train.set_index('tanggal', inplace=True)
df, lambda_ = boxcox(df_train['harga'])  # Transformasi Box-Cox
df = pd.DataFrame(df, columns=['harga'])
df = df.set_index(df_train.index)  # Set index tanggal untuk df
df_test.set_index('tanggal', inplace=True)

# %%
# import pandas as pd

# # Baca data dari file CSV
# dataset = pd.read_csv('D:\Teknik Informatika\skripsi\scraping pertanian\data_komoditas_rata-rata.csv')

# # Filter data sesuai kebutuhan
# dataset = dataset[
#     (dataset['komoditas_nama'] == 'Cabe Rawit Merah')
# ].sort_values(by='tanggal').drop(columns=['komoditas_nama', 'id', 'created_at', 'kategori_id', 'satuan'])

# # Copy untuk pemrosesan lebih lanjut
# dataraw = dataset.copy()

# dataraw['tanggal'] = pd.to_datetime(dataraw['tanggal'])
# dataraw = dataset[dataset['tanggal'] <= '2025-04-30']
# dataraw_test = dataset[dataset['tanggal'] > '2025-04-30']


# # Tampilkan dataset hasil filter
# dataraw_test

# %% [markdown]
# ## cek persiapan data

# %% [markdown]
# ### cek outlier

# %%
# boxplot
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(x=df['harga'])
plt.title("Deteksi Outlier dengan Boxplot")
plt.show()

# %%
# z-score statistik
from scipy import stats

z_scores = stats.zscore(df['harga'])  # Hitung Z-score
threshold = 3  # Ambang batas umum untuk outlier
outliers = df[abs(z_scores) > threshold]  # Data yang diidentifikasi sebagai outlier

print("Jumlah outlier ekstrem:", len(outliers))
print(outliers)
# Out:
# Jumlah outlier ekstrem: 0
# Empty DataFrame
# Columns: [harga]
# Index: []

# %% [markdown]
# ### cek distribusi data

# %%
sns.histplot(df['harga'], kde=True)
# Out:
# <Axes: xlabel='harga', ylabel='Count'>

# %% [markdown]
# # Feature Selection

# %%
print(df.head())
print(df.columns)
# Out:
#                harga
# tanggal
# 2021-01-01  1.978783
# 2021-01-02  1.978702
# 2021-01-03  1.978736
# 2021-01-04  1.978351
# 2021-01-05  1.978448
# Index(['harga'], dtype='object')

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# ## check missing value

# %%
print(df.isnull().sum())  # Cek jumlah nilai NaN di setiap kolom
# Out:
# harga    0
# dtype: int64

# %% [markdown]
# ## Normalization Min-Max

# %%
df.head()
# Out:
#                harga
# tanggal
# 2021-01-01  1.978783
# 2021-01-02  1.978702
# 2021-01-03  1.978736
# 2021-01-04  1.978351
# 2021-01-05  1.978448

# %%
# Normalisasi data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df.values)

# %%
# --- 2. Siapkan Dataset untuk Multistep Forecasting ---
def create_dataset(data, look_back=30, steps_ahead=30):
    X, y = [], []
    for i in range(len(data)-look_back-steps_ahead+1):
        X.append(data[i:(i+look_back), 0])
        y.append(data[(i+look_back):(i+look_back+steps_ahead), 0])
    return np.array(X), np.array(y)

look_back = 90  # Gunakan 30 hari terakhir
steps_ahead = 90  # Prediksi 30 hari ke depan
X, y = create_dataset(scaled_data, look_back, steps_ahead)

# Split data (80% train, 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape untuk GRU: [samples, timesteps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# # Model GRU

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler
from keras import optimizers
import numpy as np
from keras.layers import Bidirectional

# Hyperparameters
learning_rate = 0.0001
batch_size = 256
epochs = 100
steps_ahead = 90  # Pastikan ini sesuai dengan output layer

# --- Arsitektur GRU yang Dioptimasi ---

regressorGRU = Sequential([
    # Layer 1
    GRU(units=256,
        return_sequences=True,
        input_shape=(X_train.shape[1], 1),
        activation='tanh'),
    Dropout(0.3),
    
    # Layer 2 
    GRU(units=128,
        return_sequences=True,
        activation='tanh'),
    Dropout(0.3),
    
    # Layer 3
    GRU(units=64,  # Ditambah dari 32 untuk meningkatkan kapasitas
        return_sequences=False,
        activation='tanh'),
    Dropout(0.2),
    
    # Output layer
    Dense(steps_ahead)
])
# Compile dengan learning rate custom
optimizer = optimizers.Adam(learning_rate=learning_rate)
regressorGRU.compile(optimizer=optimizer, loss='mse')
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# --- Callbacks ---
def lr_scheduler(epoch, lr):
    if epoch % 10 == 0 and epoch != 0:
        return lr * 0.9  # Reduksi learning rate 10% setiap 10 epoch
    return lr

early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
scheduler = LearningRateScheduler(lr_scheduler)
callbacks = [early_stop, scheduler]

# --- Training ---
history = regressorGRU.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - loss: 0.2982 - val_loss: 0.2584 - learning_rate: 1.0000e-04
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 835ms/step - loss: 0.2933 - val_loss: 0.2521 - learning_rate: 1.0000e-04
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 835ms/step - loss: 0.2851 - val_loss: 0.2455 - learning_rate: 1.0000e-04
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 809ms/step - loss: 0.2803 - val_loss: 0.2384 - learning_rate: 1.0000e-04
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 808ms/step - loss: 0.2700 - val_loss: 0.2303 - learning_rate: 1.0000e-04
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 802ms/step - loss: 0.2649 - val_loss: 0.2209 - learning_rate: 1.0000e-04
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 750ms/step - loss: 0.2536 - val_loss: 0.2098 - learning_rate: 1.0000e-04
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 566ms/step - loss: 0.2394 - val_loss: 0.1965 - learning_rate: 1.0000e-04
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 526ms/step - loss: 0.2264 - val_loss: 0.1811 - learning_rate: 1.0000e-04
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 467ms/step - loss: 0.2057 - val_loss: 0.1646 - learning_rate: 1.0000e-04
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 525ms/step - loss: 0.1856 - val_loss: 0.1521 - learning_rate: 9.0000e-05
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 612ms/step - loss: 0.1730 - val_loss: 0.1447 - learning_rate: 9.0000e-05
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 488ms/step - loss: 0.1619 - val_loss: 0.1330 - learning_rate: 9.0000e-05
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 500ms/step - loss: 0.1489 - val_loss: 0.1219 - learning_rate: 9.0000e-05
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 580ms/step - loss: 0.1439 - val_loss: 0.1136 - learning_rate: 9.0000e-05
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 567ms/step - loss: 0.1323 - val_loss: 0.1068 - learning_rate: 9.0000e-05
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 556ms/step - loss: 0.1267 - val_loss: 0.1014 - learning_rate: 9.0000e-05
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 516ms/step - loss: 0.1213 - val_loss: 0.0962 - learning_rate: 9.0000e-05
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 556ms/step - loss: 0.1178 - val_loss: 0.0914 - learning_rate: 9.0000e-05
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 546ms/step - loss: 0.1121 - val_loss: 0.0872 - learning_rate: 9.0000e-05
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 550ms/step - loss: 0.1081 - val_loss: 0.0841 - learning_rate: 8.1000e-05
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 596ms/step - loss: 0.1038 - val_loss: 0.0814 - learning_rate: 8.1000e-05
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 520ms/step - loss: 0.1032 - val_loss: 0.0789 - learning_rate: 8.1000e-05
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 591ms/step - loss: 0.1016 - val_loss: 0.0769 - learning_rate: 8.1000e-05
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 545ms/step - loss: 0.0983 - val_loss: 0.0750 - learning_rate: 8.1000e-05
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 540ms/step - loss: 0.0977 - val_loss: 0.0734 - learning_rate: 8.1000e-05
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 532ms/step - loss: 0.0956 - val_loss: 0.0720 - learning_rate: 8.1000e-05
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 545ms/step - loss: 0.0942 - val_loss: 0.0706 - learning_rate: 8.1000e-05
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 525ms/step - loss: 0.0920 - val_loss: 0.0695 - learning_rate: 8.1000e-05
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 537ms/step - loss: 0.0903 - val_loss: 0.0685 - learning_rate: 8.1000e-05
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 505ms/step - loss: 0.0884 - val_loss: 0.0676 - learning_rate: 7.2900e-05
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - loss: 0.0874 - val_loss: 0.0669 - learning_rate: 7.2900e-05
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 492ms/step - loss: 0.0867 - val_loss: 0.0662 - learning_rate: 7.2900e-05
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 788ms/step - loss: 0.0868 - val_loss: 0.0657 - learning_rate: 7.2900e-05
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 783ms/step - loss: 0.0848 - val_loss: 0.0651 - learning_rate: 7.2900e-05
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 741ms/step - loss: 0.0854 - val_loss: 0.0646 - learning_rate: 7.2900e-05
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 560ms/step - loss: 0.0856 - val_loss: 0.0642 - learning_rate: 7.2900e-05
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 617ms/step - loss: 0.0826 - val_loss: 0.0640 - learning_rate: 7.2900e-05
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 555ms/step - loss: 0.0821 - val_loss: 0.0637 - learning_rate: 7.2900e-05
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 561ms/step - loss: 0.0818 - val_loss: 0.0632 - learning_rate: 7.2900e-05
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 466ms/step - loss: 0.0815 - val_loss: 0.0627 - learning_rate: 6.5610e-05
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 508ms/step - loss: 0.0806 - val_loss: 0.0624 - learning_rate: 6.5610e-05
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 531ms/step - loss: 0.0799 - val_loss: 0.0623 - learning_rate: 6.5610e-05
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 457ms/step - loss: 0.0797 - val_loss: 0.0620 - learning_rate: 6.5610e-05
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 741ms/step - loss: 0.0804 - val_loss: 0.0617 - learning_rate: 6.5610e-05
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 730ms/step - loss: 0.0791 - val_loss: 0.0615 - learning_rate: 6.5610e-05
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 708ms/step - loss: 0.0802 - val_loss: 0.0614 - learning_rate: 6.5610e-05
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 728ms/step - loss: 0.0781 - val_loss: 0.0613 - learning_rate: 6.5610e-05
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 748ms/step - loss: 0.0768 - val_loss: 0.0609 - learning_rate: 6.5610e-05
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 528ms/step - loss: 0.0777 - val_loss: 0.0607 - learning_rate: 6.5610e-05
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 526ms/step - loss: 0.0782 - val_loss: 0.0607 - learning_rate: 5.9049e-05
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - loss: 0.0760 - val_loss: 0.0604 - learning_rate: 5.9049e-05
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 484ms/step - loss: 0.0770 - val_loss: 0.0602 - learning_rate: 5.9049e-05
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 512ms/step - loss: 0.0751 - val_loss: 0.0602 - learning_rate: 5.9049e-05
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 505ms/step - loss: 0.0751 - val_loss: 0.0602 - learning_rate: 5.9049e-05
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 531ms/step - loss: 0.0764 - val_loss: 0.0600 - learning_rate: 5.9049e-05
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 548ms/step - loss: 0.0737 - val_loss: 0.0598 - learning_rate: 5.9049e-05
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 477ms/step - loss: 0.0738 - val_loss: 0.0596 - learning_rate: 5.9049e-05
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 525ms/step - loss: 0.0746 - val_loss: 0.0596 - learning_rate: 5.9049e-05
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 485ms/step - loss: 0.0735 - val_loss: 0.0595 - learning_rate: 5.9049e-05
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 644ms/step - loss: 0.0727 - val_loss: 0.0595 - learning_rate: 5.3144e-05
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 775ms/step - loss: 0.0733 - val_loss: 0.0594 - learning_rate: 5.3144e-05
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 772ms/step - loss: 0.0738 - val_loss: 0.0590 - learning_rate: 5.3144e-05
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 781ms/step - loss: 0.0724 - val_loss: 0.0589 - learning_rate: 5.3144e-05
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 763ms/step - loss: 0.0720 - val_loss: 0.0590 - learning_rate: 5.3144e-05
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 744ms/step - loss: 0.0724 - val_loss: 0.0588 - learning_rate: 5.3144e-05
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 778ms/step - loss: 0.0714 - val_loss: 0.0587 - learning_rate: 5.3144e-05
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 523ms/step - loss: 0.0725 - val_loss: 0.0587 - learning_rate: 5.3144e-05
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 530ms/step - loss: 0.0716 - val_loss: 0.0583 - learning_rate: 5.3144e-05
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 513ms/step - loss: 0.0705 - val_loss: 0.0583 - learning_rate: 5.3144e-05
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 494ms/step - loss: 0.0717 - val_loss: 0.0584 - learning_rate: 4.7830e-05
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 472ms/step - loss: 0.0705 - val_loss: 0.0584 - learning_rate: 4.7830e-05
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 540ms/step - loss: 0.0713 - val_loss: 0.0581 - learning_rate: 4.7830e-05
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 578ms/step - loss: 0.0711 - val_loss: 0.0579 - learning_rate: 4.7830e-05
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 530ms/step - loss: 0.0708 - val_loss: 0.0579 - learning_rate: 4.7830e-05
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 536ms/step - loss: 0.0696 - val_loss: 0.0579 - learning_rate: 4.7830e-05
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 531ms/step - loss: 0.0707 - val_loss: 0.0580 - learning_rate: 4.7830e-05
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 523ms/step - loss: 0.0697 - val_loss: 0.0581 - learning_rate: 4.7830e-05
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 541ms/step - loss: 0.0694 - val_loss: 0.0576 - learning_rate: 4.7830e-05
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - loss: 0.0676 - val_loss: 0.0574 - learning_rate: 4.7830e-05
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 515ms/step - loss: 0.0698 - val_loss: 0.0573 - learning_rate: 4.3047e-05
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - loss: 0.0683 - val_loss: 0.0573 - learning_rate: 4.3047e-05
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 818ms/step - loss: 0.0687 - val_loss: 0.0572 - learning_rate: 4.3047e-05
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 814ms/step - loss: 0.0679 - val_loss: 0.0571 - learning_rate: 4.3047e-05
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 832ms/step - loss: 0.0673 - val_loss: 0.0570 - learning_rate: 4.3047e-05
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 809ms/step - loss: 0.0684 - val_loss: 0.0573 - learning_rate: 4.3047e-05
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 825ms/step - loss: 0.0673 - val_loss: 0.0572 - learning_rate: 4.3047e-05
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 816ms/step - loss: 0.0690 - val_loss: 0.0571 - learning_rate: 4.3047e-05
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 815ms/step - loss: 0.0666 - val_loss: 0.0566 - learning_rate: 4.3047e-05
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 854ms/step - loss: 0.0669 - val_loss: 0.0565 - learning_rate: 4.3047e-05
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 807ms/step - loss: 0.0676 - val_loss: 0.0566 - learning_rate: 3.8742e-05
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 815ms/step - loss: 0.0675 - val_loss: 0.0565 - learning_rate: 3.8742e-05
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 804ms/step - loss: 0.0679 - val_loss: 0.0564 - learning_rate: 3.8742e-05
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 787ms/step - loss: 0.0666 - val_loss: 0.0563 - learning_rate: 3.8742e-05
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 809ms/step - loss: 0.0661 - val_loss: 0.0562 - learning_rate: 3.8742e-05
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 827ms/step - loss: 0.0663 - val_loss: 0.0563 - learning_rate: 3.8742e-05
# Epoch 97/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 805ms/step - loss: 0.0662 - val_loss: 0.0564 - learning_rate: 3.8742e-05
# Epoch 98/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 803ms/step - loss: 0.0662 - val_loss: 0.0562 - learning_rate: 3.8742e-05
# Epoch 99/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 813ms/step - loss: 0.0649 - val_loss: 0.0559 - learning_rate: 3.8742e-05
# Epoch 100/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 809ms/step - loss: 0.0654 - val_loss: 0.0556 - learning_rate: 3.8742e-05

# %%
# --- Walk-Forward Validation (Implementasi Lengkap) ---
def walk_forward_validation(model, data, look_back, steps_ahead, scaler):
    n = len(data)
    test_size = n - look_back - steps_ahead
    errors = []
    
    for i in range(test_size):
        # Siapkan input (look_back hari) dan target (steps_ahead hari)
        X = data[i:i+look_back]
        y_true = data[i+look_back : i+look_back+steps_ahead]
        
        # Prediksi
        X = np.reshape(X, (1, look_back, 1))
        y_pred = model.predict(X, verbose=0)
        
        # Inverse transform ke skala asli
        y_true = scaler.inverse_transform(y_true.reshape(-1, 1)).flatten()
        y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()
        
        # Hitung MAPE
        mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
        errors.append(mape)
    
    return np.mean(errors)

# %%
# df_test.set_index('tanggal', inplace=True)

# %%
from scipy.special import inv_boxcox
# --- Prediksi 30 Hari ke Depan ---
last_sequence = scaled_data[-90:]  # Ambil 30 hari terakhir
last_sequence = np.reshape(last_sequence, (1, 90, 1))
future_predictions = regressorGRU.predict(last_sequence)
future_predictions = scaler.inverse_transform(future_predictions.reshape(-1, 1)).flatten()
future_predictions = inv_boxcox(future_predictions, lambda_)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step

# %%
print(len(future_predictions))
print(len(df_test))
# Out:
# 90
# 90

# %%
# Hasil akhir
print("Prediksi 30 Hari ke Depan:")
print(pd.DataFrame({
    'tanggal': df_test.index,
    'Actual': df_test['harga'].values,
    'Prediksi_Harga': future_predictions
}))
# Out:
# Prediksi 30 Hari ke Depan:
#       tanggal  Actual  Prediksi_Harga
# 0  2025-04-02    8791     8678.220768
# 1  2025-04-03    8875     8771.340264
# 2  2025-04-04    8878     7796.932745
# 3  2025-04-05    8956     8415.327684
# 4  2025-04-06    8852     8384.717513
# ..        ...     ...             ...
# 85 2025-06-26   20721     8548.607029
# 86 2025-06-27   20872     8462.720033
# 87 2025-06-28   20837     8284.061048
# 88 2025-06-29   21137     8843.780571
# 89 2025-06-30   22568     8409.063352
#
# [90 rows x 3 columns]

# %%
# --- 7. Visualisasi Hasil ---
plt.figure(figsize=(10, 6))
# plt.plot(df.index, df['harga'], label='Data Historis', color='blue')
plt.plot(df_test, label='Aktual', color='blue')
plt.plot(df_test.index,future_predictions, label='Prediksi 30 Hari', color='red', linestyle='--')
plt.title(f'Prediksi Harga Cabai rawit Merah 30 Hari ke Depan (GRU Model)')
plt.xlabel('Tanggal')
plt.ylabel('Harga')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
# Hitung MAPE
    
# Hitung RMSE dan MAPE
rmse = np.sqrt(mean_squared_error(df_test['harga'], future_predictions))
mape = mean_absolute_percentage_error(df_test['harga'], future_predictions) * 100
mae = mean_absolute_error(df_test['harga'], future_predictions)
print(f'MAE: {mae:.2f}')
print(f'RMSE: {rmse:.2f}')
print(f'MAPE: {mape:.2f}%')
# Out:
# MAE: 4146.69
# RMSE: 5415.17
# MAPE: 28.25%
